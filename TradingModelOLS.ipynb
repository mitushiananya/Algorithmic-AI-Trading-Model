# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr
import yfinance

# %%
aapl = pdr.get_data_yahoo('AAPL', 
                          start=datetime.datetime(2020, 1, 1), 
                          end=datetime.datetime(2021, 4, 17))
# Start basic data exploration
print("First 5 rows: \n")
print(aapl.head())
print("\n")
print("Last 5 rows: \n")
aapl.tail()
# Out:
# First 5 rows:
#
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-12-31  73.419998  72.379997  72.482498  73.412498  100805600.0  72.675339
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.333511
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.610840
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.197395
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.848442
#
#
# Last 5 rows:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-04-12  132.850006  130.630005  132.520004  131.240005  91420000.0
# 2021-04-13  134.660004  131.929993  132.440002  134.429993  91266500.0
# 2021-04-14  135.000000  131.660004  134.940002  132.029999  87222800.0
# 2021-04-15  135.000000  133.639999  133.820007  134.500000  89347100.0
# 2021-04-16  134.669998  133.279999  134.300003  134.160004  84818500.0
#
# ...

# %%
# Inspect the index 
print(aapl.index)
print("\n")
# Inspect the columns
print("The columns: \n")
print(aapl.columns)

# Last 10 observations of `Close`
tec = aapl['Close'][-10:]
print("\nLast 10 observations of 'Close': \n")
print(tenclose)
# Out:
# DatetimeIndex(['2019-12-31', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08',
#                '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14',
#                '2021-04-15', '2021-04-16'],
#               dtype='datetime64[ns]', name='Date', length=326, freq=None)
#
#
# The columns:
#
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')
#
# Last 10 observations of 'Close':
#
# Date
# 2021-04-05    125.900002
# 2021-04-06    126.209999
# 2021-04-07    127.900002
# 2021-04-08    130.360001
# 2021-04-09    133.000000
# 2021-04-12    131.240005
# 2021-04-13    134.429993
# 2021-04-14    132.029999
# 2021-04-15    134.500000
# 2021-04-16    134.160004
# Name: Close, dtype: float64

# %%
# Inspect the first rows of November-December 2020
print("First rows of Nov-Dec 2020: \n")
print(aapl.loc[pd.Timestamp('2020-11-01'):pd.Timestamp('2020-12-31')].head())

# Inspect the first rows of 2021 
print("\nFirst rows of 2021: \n")
print(aapl.loc['2021'].head())
# Out:
# First rows of Nov-Dec 2020:
#
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-11-02  110.680000  107.320000  109.110001  108.769997  122866900.0
# 2020-11-03  111.489998  108.730003  109.660004  110.440002  107624400.0
# 2020-11-04  115.589996  112.349998  114.139999  114.949997  138235500.0
# 2020-11-05  119.620003  116.870003  117.949997  119.029999  126387100.0
# 2020-11-06  119.199997  116.129997  118.320000  118.690002  114457900.0
#
#              Adj Close
# Date
# 2020-11-02  108.420654
# 2020-11-03  110.085289
# 2020-11-04  114.580803
# 2020-11-05  118.647697
# 2020-11-06  118.512909
#
# First rows of 2021:
#
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-04  133.610001  126.760002  133.520004  129.410004  143301900.0
# 2021-01-05  131.740005  128.429993  128.889999  131.009995   97664900.0
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# ...

# %%
# Sample 20 rows
sample = aapl.sample(20)
# Print `sample`
print(sample)

# Resample to monthly level 
monthly_aapl = aapl.resample('M')
# Print `monthly_aapl`
print(monthly_aapl)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-11-05  119.620003  116.870003  117.949997  119.029999  126387100.0
# 2020-08-21  124.867500  119.250000  119.262497  124.370003  338054800.0
# 2021-02-26  124.849998  121.199997  122.589996  121.260002  164320000.0
# 2020-06-02   80.860001   79.732498   80.187500   80.834999   87642800.0
# 2020-09-28  115.320000  112.779999  115.010002  114.959999  137672400.0
# 2020-03-27   63.967499   61.762501   63.187500   61.935001  204216800.0
# 2021-04-05  126.160004  123.070000  123.870003  125.900002   88651200.0
# 2021-02-02  136.309998  134.610001  135.729996  134.990005   83305400.0
# 2021-01-28  141.990005  136.699997  139.520004  137.089996  142621100.0
# 2021-01-22  139.850006  135.020004  136.279999  139.070007  114459400.0
# 2021-02-01  135.380005  130.929993  133.750000  134.139999  106239800.0
# 2021-03-18  123.180000  120.320000  122.879997  120.529999  121229700.0
# ...

# %%
# Add a column `diff` to `aapl` 
aapl['diff'] = aapl.Open - aapl.Close
aapl['diff']
# Delete the new `diff` column
#del aapl['diff']
# End of the basic Data Exploration
# Out:
# Date
# 2019-12-31   -0.930000
# 2020-01-02   -1.027504
# 2020-01-03   -0.070000
# 2020-01-06   -1.502495
# 2020-01-07    0.362495
#                 ...
# 2021-04-12    1.279999
# 2021-04-13   -1.989990
# 2021-04-14    2.910004
# 2021-04-15   -0.679993
# 2021-04-16    0.139999
# Name: diff, Length: 326, dtype: float64

# %%
# Start Basic Visualisation of Data 
# Plot the closing prices for `aapl`
aapl['Close'].plot(grid=True, figsize = (15,10))
# Show the plot
plt.show()
#End Basic Visualisation of Data

# %%
# Start financial Analysis - Explore Returns

daily_close_price = aapl[['Adj Close']]
# Daily returns
daily_close_returns = daily_close_price.pct_change()
# Replace NA values with 0
daily_close_returns.fillna(0, inplace=True)
print("Daily Returns: \n")
print(daily_close_returns)

# Daily log returns
daily_log_returns = np.log(daily_close.pct_change()+1)
print("Daily log returns: \n")
print(daily_log_returns)
# Out:
# Daily Returns:
#
#             Adj Close
# Date
# 2019-12-31   0.000000
# 2020-01-02   0.022816
# 2020-01-03  -0.009722
# 2020-01-06   0.007968
# 2020-01-07  -0.004703
# ...               ...
# 2021-04-12  -0.013233
# 2021-04-13   0.024307
# 2021-04-14  -0.017853
# 2021-04-15   0.018708
# 2021-04-16  -0.002528
#
# [326 rows x 1 columns]
# Daily log returns:
#
#             Adj Close
# Date
# 2019-12-31        NaN
# 2020-01-02   0.022560
# 2020-01-03  -0.009770
# 2020-01-06   0.007937
# 2020-01-07  -0.004714
# ...               ...
# 2021-04-12  -0.013321
# 2021-04-13   0.024016
# 2021-04-14  -0.018014
# 2021-04-15   0.018535
# 2021-04-16  -0.002531
#
# [326 rows x 1 columns]

# %%
# Resample `aapl` to business months, take last observation as value 
monthly = aapl.resample('BM').apply(lambda x: x[-1])
# Calculate the monthly percentage change
monthly.pct_change()

# Resample `aapl` to quarters, take the mean as value per quarter
quarter = aapl.resample("4M").mean()
# Calculate the quarterly percentage change
quarter.pct_change()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2019-12-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2020-04-30 -0.002467 -0.019996 -0.007562 -0.017014  0.852596  -0.015443
# 2020-08-31  0.301534  0.311264  0.307558  0.307101 -0.172171   0.312086
# 2020-12-31  0.268032  0.260635  0.267950  0.261676 -0.145658   0.264544
# 2021-04-30  0.077289  0.082892  0.079794  0.080998 -0.191816   0.083080
#
#                 diff
# Date
# 2019-12-31       NaN
# 2020-04-30 -0.753693
# 2020-08-31  0.163677
# 2020-12-31 -1.952447
# 2021-04-30 -0.484668

# %%
# Plot the distribution of `daily_pct_c`
daily_pct_c.hist(bins=50, color = 'Black', figsize = (15,6))
# Show the plot
plt.show()
# Summary statistics
print(daily_pct_c.describe())
# Out:
#         Adj Close
# count  326.000000
# mean     0.002262
# std      0.027581
# min     -0.128647
# 25%     -0.011283
# 50%      0.001244
# 75%      0.016541
# max      0.119808

# %%
# Calculate the cumulative daily returns
cum_daily_return = (1 + daily_pct_c).cumprod()
# Print `cum_daily_return`
print(cum_daily_return)
# Out:
#             Adj Close
# Date
# 2019-12-31   1.000000
# 2020-01-02   1.022816
# 2020-01-03   1.012872
# 2020-01-06   1.020943
# 2020-01-07   1.016142
# ...               ...
# 2021-04-12   1.805840
# 2021-04-13   1.849733
# 2021-04-14   1.816710
# 2021-04-15   1.850697
# 2021-04-16   1.846018
#
# [326 rows x 1 columns]

# %%
# Plot the cumulative daily returns
cum_daily_return.plot(figsize=(15,8), color = 'Black')
plt.show()

# %%
# Resample the cumulative daily return to cumulative monthly return 
cum_monthly_return = cum_daily_return.resample("M").mean()
# Print the `cum_monthly_return`
print(cum_monthly_return)
# Out:
#             Adj Close
# Date
# 2019-12-31   1.000000
# 2020-01-31   1.062204
# 2020-02-29   1.061979
# 2020-03-31   0.895852
# 2020-04-30   0.929789
# 2020-05-31   1.060313
# 2020-06-30   1.183604
# 2020-07-31   1.308392
# 2020-08-31   1.608320
# 2020-09-30   1.579015
# 2020-10-31   1.596680
# 2020-11-30   1.604571
# 2020-12-31   1.748881
# 2021-01-31   1.827832
# 2021-02-28   1.809268
# 2021-03-31   1.676928
# 2021-04-30   1.792192

# %%
# Get more data from Yahoo Finance
def get(tickers, startdate, enddate):
    def data(ticker):
        return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
    datas = map (data, tickers)
    return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'MSFT', 'IBM', 'GOOG']
all_data = get(tickers, datetime.datetime(2020, 1, 1), datetime.datetime(2021, 3, 10))
all_data.head()
# Out:
#                         High        Low       Open      Close       Volume  \
# Ticker Date
# AAPL   2019-12-31  73.419998  72.379997  72.482498  73.412498  100805600.0
#        2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0
#        2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0
#        2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0
#        2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0
#
#                    Adj Close
# Ticker Date
# AAPL   2019-12-31  72.675339
#        2020-01-02  74.333511
#        2020-01-03  73.610840
#        2020-01-06  74.197395
#        2020-01-07  73.848442

# %%
# Plotting the data that I just got from Yahoo Finance
# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date', 'Ticker', 'Adj Close')
# Calculate the daily percentage change for `daily_close_px`
daily_pct_change = daily_close_px.pct_change()
# Plot the distributions
daily_pct_change.hist(bins=50, sharex=True, figsize=(18,10), color = 'Black')
# Show the resulting plot
plt.show()
# End common financial analysis - Explore returns

# %%
# Start financial analysis - Moving Windows
# Isolate the adjusted closing prices 
adj_close_px = aapl['Adj Close']
# Calculate the moving average
moving_avg = adj_close_px.rolling(window=40).mean()
# Inspect the result
moving_avg[-10:]
# Out:
# Date
# 2021-04-05    125.264499
# 2021-04-06    125.000750
# 2021-04-07    124.775500
# 2021-04-08    124.634250
# 2021-04-09    124.574500
# 2021-04-12    124.477250
# 2021-04-13    124.453750
# 2021-04-14    124.424750
# 2021-04-15    124.516250
# 2021-04-16    124.627500
# Name: Adj Close, dtype: float64

# %%
# Plot for Moving Windows
# Short moving window rolling mean
aapl['50'] = adj_close_px.rolling(window=50).mean()
# Long moving window rolling mean
aapl['250'] = adj_close_px.rolling(window=250).mean()
# Plot the adjusted closing price, the short and long windows of rolling means
aapl[['Adj Close', '50', '250']].plot(figsize = (15,8), cmap="Set2")
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.facecolor'] = 'white'
plt.show()
# End of financial analysis - Moving Windows

# %%
# Start financial analysis - Volatility Calculation
# Define the minumum of periods to consider 
min_periods = 85 
# Calculate the volatility
vol = daily_pct_change.rolling(min_periods).std() * np.sqrt(min_periods) 
# Plot the volatility
vol.plot(figsize=(10, 8))
# Show the plot
plt.rcParams['figure.facecolor'] = 'white'
plt.show()
# End of financial analysis - Volatility Calculation

# %%
# Start Statistical Analysis using Ordinary Least-Squares Regression (OLS) model/algorithm
# Import the `api` model of `statsmodels` under alias `sm`
import statsmodels.api as sm

# Isolate the adjusted closing price
all_adj_close = all_data[['Adj Close']]

# Calculate the returns 
all_returns = np.log(all_adj_close / all_adj_close.shift(1))

# Isolate the AAPL returns 
aapl_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'AAPL']
aapl_returns.index = aapl_returns.index.droplevel('Ticker')

# Isolate the MSFT returns
msft_returns = all_returns.iloc[all_returns.index.get_level_values('Ticker') == 'MSFT']
msft_returns.index = msft_returns.index.droplevel('Ticker')

# Build up a new DataFrame with AAPL and MSFT returns
return_data = pd.concat([aapl_returns, msft_returns], axis=1)[1:] # Variable y
return_data.columns = ['AAPL', 'MSFT']

# Add a constant 
X = sm.add_constant(return_data['AAPL'])

# Construct the model by performing the regression and fitting the model
model = sm.OLS(return_data['MSFT'],X).fit()

# Print the summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MSFT   R-squared:                       0.691
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     662.7
# Date:                Sat, 17 Apr 2021   Prob (F-statistic):           1.27e-77
# Time:                        18:41:23   Log-Likelihood:                 839.79
# No. Observations:                 299   AIC:                            -1676.
# Df Residuals:                     297   BIC:                            -1668.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.218e-05      0.001      0.062      0.951      -0.002       0.002
# ...

# %%
# Plotting the above summary in scatter plot
# Plot returns of AAPL and MSFT
plt.plot(return_data['AAPL'], return_data['MSFT'], 'r.')
# Add an axis to the plot
ax = plt.axis()
# Initialize `x`
x = np.linspace(ax[0], ax[1] + 0.01)
# Plot the regression line
plt.plot(x, model.params[0] + model.params[1] * x, 'b', lw=2)
# Customize the plot
plt.grid(True)
plt.axis('tight')
plt.xlabel('Apple Returns')
plt.ylabel('Microsoft returns')
plt.rcParams['figure.facecolor'] = 'white'
plt.show()

# %%
# Trading Strategy 
# Initialize the short and long windows
short_window = 40
long_window = 100

# Initialize the `signals` DataFrame with the `signal` column
signals = pd.DataFrame(index=aapl.index)
signals['signal'] = 0.0

# Create short simple moving average over the short window
signals['short_mavg'] = aapl['Close'].rolling(window=short_window, min_periods=1, center=False).mean()

# Create long simple moving average over the long window
signals['long_mavg'] = aapl['Close'].rolling(window=long_window, min_periods=1, center=False).mean()

# Create signals
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] 
                                            > signals['long_mavg'][short_window:], 1.0, 0.0)   

# Generate trading orders
signals['positions'] = signals['signal'].diff()
print(signals)
#signals.to_csv('sig.csv')
# Out:
#             signal  short_mavg   long_mavg  positions
# Date
# 2019-12-31     0.0   73.412498   73.412498        NaN
# 2020-01-02     0.0   74.250000   74.250000        0.0
# 2020-01-03     0.0   74.285833   74.285833        0.0
# 2020-01-06     0.0   74.451874   74.451874        0.0
# 2020-01-07     0.0   74.481000   74.481000        0.0
# ...            ...         ...         ...        ...
# 2021-04-12     0.0  124.477250  127.022300        0.0
# 2021-04-13     0.0  124.453750  127.163600        0.0
# 2021-04-14     0.0  124.424750  127.290000        0.0
# 2021-04-15     0.0  124.516250  127.454700        0.0
# 2021-04-16     0.0  124.627500  127.609900        0.0
#
# [326 rows x 4 columns]

# %%
# Plotting the trading strategy
# Initialize the plot figure
fig = plt.figure(figsize = (10,6))

# Add a subplot and label for y-axis
ax1 = fig.add_subplot(111,  ylabel='Price in $')

# Plot the closing price
aapl['Close'].plot(ax=ax1, color='r', lw=2.)

# Plot the short and long moving averages
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

# Plot the buy signals
ax1.plot(signals.loc[signals.positions == 1.0].index, 
         signals.short_mavg[signals.positions == 1.0],
         '^', markersize=10, color='m', label = 'Buying Signal')
         
# Plot the sell signals
ax1.plot(signals.loc[signals.positions == -1.0].index, 
         signals.short_mavg[signals.positions == -1.0],
         'v', markersize=10, color='g', label = 'Selling Signal')
         
# Show the plot
plt.show()
# End of trading strategy

# %%
# Backtesting the strategy
# Set the initial capital
initial_capital= float(100000.0)

# Create a DataFrame `positions`
positions = pd.DataFrame(index=signals.index).fillna(0.0)

# Buy a 100 shares
positions['AAPL'] = 100*signals['signal']   
  
# Initialize the portfolio with value owned   
portfolio = positions.multiply(aapl['Adj Close'], axis=0)

# Store the difference in shares owned 
pos_diff = positions.diff()

# Add `holdings` to portfolio
portfolio['holdings'] = (positions.multiply(aapl['Adj Close'], axis=0)).sum(axis=1)

# Add `cash` to portfolio
portfolio['cash'] = initial_capital - (pos_diff.multiply(aapl['Adj Close'], axis=0)).sum(axis=1).cumsum()   

# Add `total` to portfolio
portfolio['total'] = portfolio['cash'] + portfolio['holdings']

# Add `returns` to portfolio
portfolio['returns'] = portfolio['total'].pct_change()
print(portfolio.head())
# Out:
#             AAPL  holdings      cash     total  returns
# Date
# 2019-12-31   0.0       0.0  100000.0  100000.0      NaN
# 2020-01-02   0.0       0.0  100000.0  100000.0      0.0
# 2020-01-03   0.0       0.0  100000.0  100000.0      0.0
# 2020-01-06   0.0       0.0  100000.0  100000.0      0.0
# 2020-01-07   0.0       0.0  100000.0  100000.0      0.0

# %%
fig = plt.figure()

ax1 = fig.add_subplot(111, ylabel='Portfolio value in $')

# Plot the equity curve in dollars
portfolio['total'].plot(ax=ax1, lw=2.)

# Plot the "buy" trades against the equity curve
ax1.plot(portfolio.loc[signals.positions == 1.0].index, 
         portfolio.total[signals.positions == 1.0],
         '^', markersize=10, color='r')

# Plot the "sell" trades against the equity curve
ax1.plot(portfolio.loc[signals.positions == -1.0].index, 
         portfolio.total[signals.positions == -1.0],
         'v', markersize=10, color='g')

# Show the plot
plt.show()
# End of Backtesting strategy

# %%
# Evaluating Moving Average - 1. Sharpe Ratio
# Isolate the returns of your strategy
returns = portfolio['returns']
# annualized Sharpe ratio
sharpe_ratio = np.sqrt(252) * (returns.mean() / returns.std())
# Print the Sharpe ratio
print(sharpe_ratio)
# Out:
# 0.6825780298414519

# %%
# Evaluating Moving Average - 2. Maximum Drawdown
# Define a trailing 252 trading day window
window = 252

# Calculate the max drawdown in the past window days for each day
rolling_max = aapl['Adj Close'].rolling(window, min_periods=1).max()
daily_drawdown = aapl['Adj Close']/rolling_max - 1.0

# Calculate the minimum (negative) daily drawdown
max_daily_drawdown = daily_drawdown.rolling(window, min_periods=1).min()

# Plot the results
daily_drawdown.plot()
max_daily_drawdown.plot()

# Show the plot
plt.show()
